# %%
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort

from IPython.display import clear_output

import glob

# %%
from player_tracker import PlayerTracker
from process_video import process_video

# %%
# Check for video files (*.mp4) in the current folder
video_files = glob.glob("*.mp4")
if video_files:
    video = video_files[0]  # Use the first video file found
    print(f"Video file found: {video}")
else:
    video = input('Enter the path to your video file (e.g., "video.mp4"): ')

# Check for weight files (*.pt) in the current folder
weight_files = glob.glob("*.pt")
if weight_files:
    weights = weight_files[0]  # Use the first weight file found
    print(f"Weight file found: {weights}")
else:
    weights = input('Enter the desired output video file name (e.g., "best.pt"): ')

# %%
model = YOLO(weights, verbose=False)
print("Weight loaded successfully.")
# Out:
# Weight loaded successfully.

# %%
tracker = PlayerTracker()

# %%
process_video(video, model, tracker)
# Out:
# 0: 384x640 1 ball, 16 players, 2 referees, 902.8ms
# Speed: 3.5ms preprocess, 902.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 2 referees, 1151.1ms
# Speed: 4.0ms preprocess, 1151.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 1155.3ms
# Speed: 2.2ms preprocess, 1155.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 893.4ms
# Speed: 2.2ms preprocess, 893.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 834.6ms
# Speed: 3.4ms preprocess, 834.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 836.8ms
# Speed: 2.0ms preprocess, 836.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 842.0ms
# ...
